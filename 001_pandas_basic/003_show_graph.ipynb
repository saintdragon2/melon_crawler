# %% [markdown]
# # Seaborn으로 그래프 그리기

# %%
import seaborn as sns
import pandas as pd

df = pd.DataFrame([['Alice', 10], ['Brown', 20], ['Chalie', 30]], columns=['name', 'value'])
df
# Out:
#      name  value
# 0   Alice     10
# 1   Brown     20
# 2  Chalie     30

# %%
sns.barplot(data=df, x='name', y='value')
# Out:
# <AxesSubplot:xlabel='name', ylabel='value'>

# %%
df = pd.DataFrame([['홍길동', 10], ['Brown', 20], ['Chalie', 30]], columns=['name', 'value'])
df
# Out:
#      name  value
# 0     홍길동     10
# 1   Brown     20
# 2  Chalie     30

# %%
# 한글이 섞이면 안 된다. 
sns.barplot(data=df, x='name', y='value')
# Out:
# <AxesSubplot:xlabel='name', ylabel='value'>
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 44600 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\saint\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.set(font="Malgun Gothic", 
        rc={"axes.unicode_minus":False},
        style='white'
        )

# %%
sns.barplot(data=df, x='name', y='value')
# Out:
# <AxesSubplot:xlabel='name', ylabel='value'>

# %%
# 2020년 멜론차트를 그래프로 그려보자. 
df_2020 = pd.read_excel('./output/kpop_2020.xlsx')
df_2020
# Out:
#      Unnamed: 0  artist_id  point        artist_name  song_cnt  \
# 0             0     672375  25779              방탄소년단        27
# 1             1     261143  15681                아이유         9
# 2             2     752425  10129                 폴킴         8
# 3             3     774900   6197       창모 (CHANGMO)         6
# 4             4     857994   5699  오마이걸 (OH MY GIRL)         2
# ..          ...        ...    ...                ...       ...
# 187         187    2754958      3                유산슬         1
# 188         188    2007040      3         로시 (Rothy)         1
# 189         189     960278      3              NCT U         1
# 190         190     585492      2               기리보이         2
# 191         191    2639564      1                정효빈         1
#
#                                            song_titles  rank
# 0    작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey);봄날;I...     1
# 1    Blueming;Love poem;시간의 바깥;unlucky;미리 메리 크리스마스 ...     1
# 2    안녕;모든 날, 모든 순간 (Every day, Every Moment);너를 만나...     5
# 3    METEOR;빌었어;BAND;PAY DAY (Prod. GRAY);COUNTIN M...     1
# 4                             살짝 설렜어 (Nonstop);Dolphin     2
# ..                                                 ...   ...
# 187                                            사랑의 재개발    98
# 188                               OCEAN VIEW (Feat.찬열)    98
# 189                        Make A Wish (Birthday Song)    98
# 190                               연기 (With 헤이즈);사랑이었나봐   100
# 191                                                가끔은   100
#
# [192 rows x 7 columns]

# %%
df_2020.drop(columns=['Unnamed: 0'], inplace=True)
df_2020
# Out:
#      artist_id  point        artist_name  song_cnt  \
# 0       672375  25779              방탄소년단        27
# 1       261143  15681                아이유         9
# 2       752425  10129                 폴킴         8
# 3       774900   6197       창모 (CHANGMO)         6
# 4       857994   5699  오마이걸 (OH MY GIRL)         2
# ..         ...    ...                ...       ...
# 187    2754958      3                유산슬         1
# 188    2007040      3         로시 (Rothy)         1
# 189     960278      3              NCT U         1
# 190     585492      2               기리보이         2
# 191    2639564      1                정효빈         1
#
#                                            song_titles  rank
# 0    작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey);봄날;I...     1
# 1    Blueming;Love poem;시간의 바깥;unlucky;미리 메리 크리스마스 ...     1
# 2    안녕;모든 날, 모든 순간 (Every day, Every Moment);너를 만나...     5
# 3    METEOR;빌었어;BAND;PAY DAY (Prod. GRAY);COUNTIN M...     1
# 4                             살짝 설렜어 (Nonstop);Dolphin     2
# ..                                                 ...   ...
# 187                                            사랑의 재개발    98
# 188                               OCEAN VIEW (Feat.찬열)    98
# 189                        Make A Wish (Birthday Song)    98
# 190                               연기 (With 헤이즈);사랑이었나봐   100
# 191                                                가끔은   100
#
# [192 rows x 6 columns]

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(figsize=(20, 30))
sns.barplot(data=df_2020.head(90), x='point', y='artist_name')
# Out:
# <AxesSubplot:xlabel='point', ylabel='artist_name'>
